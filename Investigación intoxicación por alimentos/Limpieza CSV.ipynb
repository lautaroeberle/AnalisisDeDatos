# %%
import pandas as pd


df = pd.read_csv("Registro para la obtención de camisetas.csv")

df_sin_marca_temporal = df.drop(columns=["Marca temporal"])


df_sin_marca_temporal.to_csv("archivo_sin_marca_temporal.csv", index=False)
